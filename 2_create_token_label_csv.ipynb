# %%
import numpy as np
import pandas as pd
import os
import logging
import csv
import re # Import regular expressions

# --- Configuration (Ensure these match your notebook setup) ---
T_HOURS = 48
N_BINS = 20
SEED = 0
logger = logging.getLogger("CombinedTokenInfo")

PROJECT_ROOT = "/changed" # Adjust if needed
DATA_ROOT_DIR = os.path.join(PROJECT_ROOT, "final_data") # Or your output_dir
RESULTS_DIR = os.path.join(PROJECT_ROOT, "results")

# --- Paths ---
dict_dir = os.path.join(DATA_ROOT_DIR, 'dictionaries')
token_map_path = os.path.join(dict_dir, f'{T_HOURS}_{SEED}_{N_BINS}-token2index.npy')
boundaries_path = os.path.join(dict_dir, f'{T_HOURS}_{SEED}_{N_BINS}-bin_boundaries.npy') # Needs to be generated by modified script 7
value_dict_path = os.path.join(dict_dir, f'{T_HOURS}-{SEED}-values.npy') # Generated by script 6
d_items_path = '/D_ITEMS.csv'
d_labitems_path = '/D_LABITEMS.csv'

# Define the output CSV file path
output_csv_path = os.path.join(dict_dir, f'{T_HOURS}_{SEED}_{N_BINS}-token_combined_info.csv')
logger.info(f"Combined token info CSV will be saved to: {output_csv_path}")
os.makedirs(os.path.dirname(output_csv_path), exist_ok=True) # Ensure directory exists

logger.info("--- Starting Combined Token Info Generation ---")

# --- 1. Load Token Map ---
try:
    logger.info(f"Loading token map from: {token_map_path}")
    token2index = np.load(token_map_path, allow_pickle=True).item()
    index2token = {v: k for k, v in token2index.items()}
    logger.info(f"Loaded {len(token2index)} tokens.")
except FileNotFoundError:
    logger.error(f"Error: Token map file not found at {token_map_path}")
    raise
except Exception as e:
    logger.error(f"Error loading token map: {e}")
    raise

# --- 2. Load Bin Boundaries ---
try:
    logger.info(f"Loading bin boundaries from: {boundaries_path}")
    bin_boundaries = np.load(boundaries_path, allow_pickle=True).item()
    logger.info(f"Loaded boundaries for {len(bin_boundaries)} binned variables.")
except FileNotFoundError:
    logger.error(f"Error: Bin boundaries file not found at {boundaries_path}. Did you modify and re-run script 7?")
    raise
except Exception as e:
    logger.error(f"Error loading bin boundaries: {e}")
    raise

# --- 3. Load Value Dictionary ---
try:
    logger.info(f"Loading value dictionary from: {value_dict_path}")
    value_dictionary = np.load(value_dict_path, allow_pickle=True).item()
    logger.info(f"Loaded value dictionary for {len(value_dictionary)} ITEMID_UOM keys.")
except FileNotFoundError:
    logger.error(f"Error: Value dictionary file not found at {value_dict_path}")
    raise
except Exception as e:
    logger.error(f"Error loading value dictionary: {e}")
    raise

# --- 4. Load MIMIC Dictionary CSVs ---
itemid_to_label = {}
try:
    # (Loading D_ITEMS and D_LABITEMS - same as before)
    logger.info(f"Loading D_ITEMS from: {d_items_path}")
    d_items_df = pd.read_csv(d_items_path, usecols=['ITEMID', 'LABEL'])
    itemid_to_label.update(pd.Series(d_items_df.LABEL.values, index=d_items_df.ITEMID).to_dict())
    logger.info(f"Loading D_LABITEMS from: {d_labitems_path}")
    d_labitems_df = pd.read_csv(d_labitems_path, usecols=['ITEMID', 'LABEL'])
    itemid_to_label.update(pd.Series(d_labitems_df.LABEL.values, index=d_labitems_df.ITEMID).to_dict())
    logger.info(f"Created combined ITEMID->Label map with {len(itemid_to_label)} unique entries.")
except FileNotFoundError as e:
    logger.error(f"Error: MIMIC dictionary CSV not found - {e}")
    raise
except Exception as e:
    logger.error(f"Error loading or processing MIMIC dictionaries: {e}")
    raise

# --- 5. Process Tokens and Gather Information ---
logger.info("--- Generating Combined Token Information ---")
combined_data = []
binned_token_pattern = re.compile(r":(\d+)$") # Checks if suffix is purely numeric

sorted_indices = sorted(index2token.keys())

for index in sorted_indices:
    token_string = index2token[index]
    clinical_label = "<Special Token>"
    itemid_parsed = None
    value_range_str = ""  # For binned tokens
    possible_values_str = "" # For discrete/non-binned tokens
    token_type = "Special"

    if token_string not in ['<PAD>', '<UNK>']:
        try:
            # Get Clinical Label (Common Step)
            itemid_str = token_string.split('_')[0]
            itemid = int(itemid_str)
            itemid_parsed = itemid
            clinical_label = itemid_to_label.get(itemid, "<Unknown ITEMID>")

            # Check if token is binned
            match = binned_token_pattern.search(token_string)
            if match:
                # --- Handle Binned Token ---
                token_type = "Binned Continuous"
                bin_index = int(match.group(1))
                itemid_uom_key = token_string[:match.start()]

                if itemid_uom_key in bin_boundaries:
                    boundaries = bin_boundaries[itemid_uom_key]
                    if 0 <= bin_index < len(boundaries) - 1:
                        lower_bound = boundaries[bin_index]
                        upper_bound = boundaries[bin_index + 1]
                        value_range_str = f"[{lower_bound:.4f}, {upper_bound:.4f})"
                    else:
                        logger.warning(f"Token '{token_string}' has invalid bin index {bin_index}.")
                        value_range_str = "<Invalid Bin Index>"
                else:
                     logger.warning(f"Binned token '{token_string}' key '{itemid_uom_key}' not found in boundaries.")
                     value_range_str = "<Boundaries Not Found>"

            else:
                # --- Handle Discrete or Non-Binned Token ---
                token_type = "Discrete/Non-Binned"
                value_suffix = token_string.split(':')[-1] if ':' in token_string else '<No Value Suffix>'
                itemid_uom_key = token_string[:-(len(value_suffix)+1)] if ':' in token_string else token_string

                if itemid_uom_key in value_dictionary:
                    possible_disc_values = value_dictionary[itemid_uom_key].get('disc', [])
                    all_possible = sorted(list(set(map(str, possible_disc_values))))
                    if all_possible:
                         # Limit number of displayed values if too many
                         max_display = 20
                         display_values = all_possible[:max_display]
                         possible_values_str = ", ".join(display_values)
                         if len(all_possible) > max_display:
                             possible_values_str += f", ... ({len(all_possible) - max_display} more)"
                    else:
                         possible_values_str = "<No discrete values listed>"
                else:
                    possible_values_str = "<ITEMID_UOM not in values.npy>"

        except Exception as e:
            logger.warning(f"Error processing token '{token_string}': {e}")
            clinical_label = "<Processing Error>"
            token_type = "Error"

    # Append data for this token
    combined_data.append({
        'Index': index,
        'Token': token_string,
        'ITEMID': itemid_parsed if itemid_parsed is not None else '',
        'Label': clinical_label,
        'Type': token_type,
        'Value_Range (for Binned)': value_range_str,
        'Possible_Discrete_Values (from Training)': possible_values_str
    })

# --- 6. Create DataFrame and Save to CSV ---
try:
    logger.info(f"Creating combined DataFrame with {len(combined_data)} rows.")
    combined_df = pd.DataFrame(combined_data)

    # Sort DataFrame (optional)
    combined_df.sort_values(by=['Index'], inplace=True)

    logger.info(f"Saving combined token info to CSV: {output_csv_path}")
    combined_df.to_csv(output_csv_path, index=False, quoting=csv.QUOTE_ALL)
    logger.info("Successfully saved CSV.")

except Exception as e:
    logger.error(f"Error creating or saving combined DataFrame to CSV: {e}")
    raise

logger.info("--- Combined Token Info Generation Finished ---")
# Out:
# Binned token '220046_bpm:120' key '220046_bpm' not found in boundaries.
# Binned token '220047_bpm:50' key '220047_bpm' not found in boundaries.
# Binned token '220047_bpm:60' key '220047_bpm' not found in boundaries.
# Binned token '220056_mmHg:80' key '220056_mmHg' not found in boundaries.
# Binned token '220056_mmHg:90' key '220056_mmHg' not found in boundaries.
# Binned token '220058_mmHg:160' key '220058_mmHg' not found in boundaries.
# Token '220060_mmHg:16' has invalid bin index 16.
# Token '220061_mmHg:19' has invalid bin index 19.
# Token '220074_mmHg:17' has invalid bin index 17.
# Token '220210_insp/min:17' has invalid bin index 17.
# Binned token '220227_%:92' key '220227_%' not found in boundaries.
# Binned token '220227_%:96' key '220227_%' not found in boundaries.
# Binned token '220227_%:97' key '220227_%' not found in boundaries.
# Binned token '220227_%:98' key '220227_%' not found in boundaries.
# Binned token '220227_%:99' key '220227_%' not found in boundaries.
# Token '220274_units:19' has invalid bin index 19.
# Token '220277_%:9' has invalid bin index 9.
# Token '220292_L/min:6' has invalid bin index 6.
# Token '220293_L/min:3' has invalid bin index 3.
# Binned token '220339_cmH2O:5' key '220339_cmH2O' not found in boundaries.
# Binned token '220339_cmH2O:8' key '220339_cmH2O' not found in boundaries.
# Token '220615_mg/dL:19' has invalid bin index 19.
# Token '220621_:19' has invalid bin index 19.
# Token '220645_mEq/L:16' has invalid bin index 16.
# Binned token '220734_units:5' key '220734_units' not found in boundaries.
# Binned token '220734_units:6' key '220734_units' not found in boundaries.
# Token '220765_mmHg:18' has invalid bin index 18.
# Binned token '223679_mEq/L:24' key '223679_mEq/L' not found in boundaries.
# Token '223751_mmHg:5' has invalid bin index 5.
# Token '223752_mmHg:4' has invalid bin index 4.
# Token '223763_mmHg:18' has invalid bin index 18.
# Binned token '223769_%:100' key '223769_%' not found in boundaries.
# Binned token '223770_%:90' key '223770_%' not found in boundaries.
# Binned token '223770_%:93' key '223770_%' not found in boundaries.
# Token '223772_%:16' has invalid bin index 16.
# Binned token '223834_L/min:2' key '223834_L/min' not found in boundaries.
# Binned token '223834_L/min:4' key '223834_L/min' not found in boundaries.
# Binned token '223835_:100' key '223835_' not found in boundaries.
# Binned token '223835_:30' key '223835_' not found in boundaries.
# Binned token '223835_:35' key '223835_' not found in boundaries.
# Binned token '223835_:40' key '223835_' not found in boundaries.
# Binned token '223835_:50' key '223835_' not found in boundaries.
# Binned token '223835_:60' key '223835_' not found in boundaries.
# Binned token '223835_:70' key '223835_' not found in boundaries.
# Binned token '223835_:80' key '223835_' not found in boundaries.
# Binned token '223872_?C:37' key '223872_?C' not found in boundaries.
# Binned token '223873_cmH2O:30' key '223873_cmH2O' not found in boundaries.
# Binned token '223873_cmH2O:40' key '223873_cmH2O' not found in boundaries.
# Binned token '223873_cmH2O:45' key '223873_cmH2O' not found in boundaries.
# Token '223874_mL:3' has invalid bin index 3.
# Binned token '223875_insp/min:10' key '223875_insp/min' not found in boundaries.
# Binned token '223875_insp/min:20' key '223875_insp/min' not found in boundaries.
# Binned token '223875_insp/min:35' key '223875_insp/min' not found in boundaries.
# Binned token '223875_insp/min:40' key '223875_insp/min' not found in boundaries.
# Binned token '223876_sec:20' key '223876_sec' not found in boundaries.
# Token '224151_mmHg:15' has invalid bin index 15.
# Token '224152_mmHg:19' has invalid bin index 19.
# Binned token '224161_insp/min:30' key '224161_insp/min' not found in boundaries.
# Binned token '224161_insp/min:35' key '224161_insp/min' not found in boundaries.
# Binned token '224162_insp/min:8' key '224162_insp/min' not found in boundaries.
# Binned token '224169_:6' key '224169_' not found in boundaries.
# Binned token '224172_:6' key '224172_' not found in boundaries.
# Token '224191_mL:16' has invalid bin index 16.
# Binned token '224417_cmH2O:22' key '224417_cmH2O' not found in boundaries.
# Token '224422_bpm:18' has invalid bin index 18.
# Token '224654_mmHg:19' has invalid bin index 19.
# Token '224663_:15' has invalid bin index 15.
# Token '224665_:18' has invalid bin index 18.
# Token '224684_mL:6' has invalid bin index 6.
# Token '224686_mL:16' has invalid bin index 16.
# Binned token '224688_insp/min:14' key '224688_insp/min' not found in boundaries.
# Binned token '224688_insp/min:16' key '224688_insp/min' not found in boundaries.
# Binned token '224688_insp/min:18' key '224688_insp/min' not found in boundaries.
# Binned token '224688_insp/min:20' key '224688_insp/min' not found in boundaries.
# Binned token '224688_insp/min:24' key '224688_insp/min' not found in boundaries.
# Binned token '224688_insp/min:26' key '224688_insp/min' not found in boundaries.
# Token '224689_insp/min:2' has invalid bin index 2.
# Token '224690_insp/min:15' has invalid bin index 15.
# Token '224695_cmH2O:18' has invalid bin index 18.
# Token '224696_cmH2O:15' has invalid bin index 15.
# Token '224697_cmH2O:12' has invalid bin index 12.
# Binned token '224701_cmH2O:10' key '224701_cmH2O' not found in boundaries.
# Binned token '224701_cmH2O:14' key '224701_cmH2O' not found in boundaries.
# Binned token '224701_cmH2O:20' key '224701_cmH2O' not found in boundaries.
# Binned token '224701_cmH2O:5' key '224701_cmH2O' not found in boundaries.
# Binned token '224701_cmH2O:8' key '224701_cmH2O' not found in boundaries.
# Binned token '224738_sec:1' key '224738_sec' not found in boundaries.
# Token '224828_mEq/L:17' has invalid bin index 17.
# Token '225638_%:11' has invalid bin index 11.
# Token '225640_%:13' has invalid bin index 13.
# Binned token '225684_mOsm/kg:345' key '225684_mOsm/kg' not found in boundaries.
# Token '225698_mEq/L:18' has invalid bin index 18.
# Token '225807_mL:18' has invalid bin index 18.
# Binned token '226062_mmHg:45' key '226062_mmHg' not found in boundaries.
# Token '226063_mmHg:17' has invalid bin index 17.
# Binned token '226183_kcal/kg:25' key '226183_kcal/kg' not found in boundaries.
# Binned token '226253_%:85' key '226253_%' not found in boundaries.
# Binned token '226253_%:88' key '226253_%' not found in boundaries.
# Token '226329_?C:19' has invalid bin index 19.
# Token '226534_mEq/L:13' has invalid bin index 13.
# Token '226536_mEq/L:16' has invalid bin index 16.
# Token '226540_%:19' has invalid bin index 19.
# Token '226707_Inch:16' has invalid bin index 16.
# Token '226730_cm:16' has invalid bin index 16.
# Token '226846_kg:19' has invalid bin index 19.
# Token '226871_:5' has invalid bin index 5.
# Binned token '226873_:1' key '226873_' not found in boundaries.
# Token '227073_mEq/L:14' has invalid bin index 14.
# Token '227442_mEq/L:17' has invalid bin index 17.
# Token '227443_mEq/L:17' has invalid bin index 17.
# Token '227445_ng/mL:15' has invalid bin index 15.
# Binned token '227446_pg/mL:2407' key '227446_pg/mL' not found in boundaries.
# Binned token '227446_pg/mL:6439' key '227446_pg/mL' not found in boundaries.
# Token '227456_g/dL:16' has invalid bin index 16.
# Binned token '227461_ug/mL:9' key '227461_ug/mL' not found in boundaries.
# Token '227464_mEq/L:19' has invalid bin index 19.
# Token '227467_:15' has invalid bin index 15.
# Token '227516_mmHg:18' has invalid bin index 18.
# Token '227549_%:19' has invalid bin index 19.
# Token '227565_:12' has invalid bin index 12.
# Token '227566_:15' has invalid bin index 15.
# Token '227632_?C:19' has invalid bin index 19.
# Token '227634_?C:16' has invalid bin index 16.
# Binned token '40048_:0' key '40048_' not found in boundaries.
# Token '40048_ml:15' has invalid bin index 15.
# Token '40049_ml:10' has invalid bin index 10.
# Binned token '40051_ml:0' key '40051_ml' not found in boundaries.
# Binned token '40051_ml:200' key '40051_ml' not found in boundaries.
# Binned token '40051_ml:50' key '40051_ml' not found in boundaries.
# Binned token '40052_:0' key '40052_' not found in boundaries.
# Binned token '40052_ml:0' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:100' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:120' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:150' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:200' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:300' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:400' key '40052_ml' not found in boundaries.
# Binned token '40052_ml:50' key '40052_ml' not found in boundaries.
# Binned token '40053_:0' key '40053_' not found in boundaries.
# Binned token '40053_ml:1100' key '40053_ml' not found in boundaries.
# Binned token '40053_ml:500' key '40053_ml' not found in boundaries.
# Binned token '40054_ml:0' key '40054_ml' not found in boundaries.
# Binned token '40054_ml:100' key '40054_ml' not found in boundaries.
# Binned token '40054_ml:15' key '40054_ml' not found in boundaries.
# Binned token '40054_ml:150' key '40054_ml' not found in boundaries.
# Binned token '40054_ml:200' key '40054_ml' not found in boundaries.
# Binned token '40054_ml:50' key '40054_ml' not found in boundaries.
# Binned token '40055_:0' key '40055_' not found in boundaries.
# Token '40055_ml:18' has invalid bin index 18.
# Token '40057_ml:16' has invalid bin index 16.
# Token '40058_ml:17' has invalid bin index 17.
# Binned token '40059_:0' key '40059_' not found in boundaries.
# Token '40059_ml:15' has invalid bin index 15.
# Binned token '40060_:0' key '40060_' not found in boundaries.
# Binned token '40060_ml:0' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:260' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:375' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:400' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:642' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:675' key '40060_ml' not found in boundaries.
# Binned token '40060_ml:950' key '40060_ml' not found in boundaries.
# Binned token '40061_:0' key '40061_' not found in boundaries.
# Token '40061_ml:18' has invalid bin index 18.
# Binned token '40063_ml:0' key '40063_ml' not found in boundaries.
# Binned token '40063_ml:100' key '40063_ml' not found in boundaries.
# Binned token '40063_ml:150' key '40063_ml' not found in boundaries.
# Binned token '40063_ml:200' key '40063_ml' not found in boundaries.
# Binned token '40063_ml:50' key '40063_ml' not found in boundaries.
# Binned token '40063_ml:75' key '40063_ml' not found in boundaries.
# Binned token '40064_:0' key '40064_' not found in boundaries.
# Binned token '40064_ml:300' key '40064_ml' not found in boundaries.
# Binned token '40064_ml:450' key '40064_ml' not found in boundaries.
# Binned token '40064_ml:500' key '40064_ml' not found in boundaries.
# Binned token '40065_:0' key '40065_' not found in boundaries.
# Binned token '40067_:0' key '40067_' not found in boundaries.
# Binned token '40067_ml:150' key '40067_ml' not found in boundaries.
# Binned token '40067_ml:200' key '40067_ml' not found in boundaries.
# Binned token '40067_ml:400' key '40067_ml' not found in boundaries.
# Binned token '40067_ml:500' key '40067_ml' not found in boundaries.
# Binned token '40069_:0' key '40069_' not found in boundaries.
# Token '40069_ml:15' has invalid bin index 15.
# Token '40071_ml:16' has invalid bin index 16.
# Binned token '40072_ml:5' key '40072_ml' not found in boundaries.
# Binned token '40072_ml:50' key '40072_ml' not found in boundaries.
# Binned token '40072_ml:60' key '40072_ml' not found in boundaries.
# Binned token '40073_:0' key '40073_' not found in boundaries.
# Binned token '40073_ml:75' key '40073_ml' not found in boundaries.
# Binned token '40074_:0' key '40074_' not found in boundaries.
# Binned token '40074_ml:200' key '40074_ml' not found in boundaries.
# Binned token '40076_:0' key '40076_' not found in boundaries.
# Token '40076_ml:14' has invalid bin index 14.
# Binned token '40077_ml:0' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:1' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:10' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:12' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:2' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:20' key '40077_ml' not found in boundaries.
# Binned token '40077_ml:40' key '40077_ml' not found in boundaries.
# Binned token '40087_ml:200' key '40087_ml' not found in boundaries.
# Token '40094_ml:18' has invalid bin index 18.
# Binned token '40288_:0' key '40288_' not found in boundaries.
# Binned token '40288_ml:125' key '40288_ml' not found in boundaries.
# Binned token '40289_ml:100' key '40289_ml' not found in boundaries.
# Binned token '40289_ml:225' key '40289_ml' not found in boundaries.
# Binned token '40367_ml:424' key '40367_ml' not found in boundaries.
# Binned token '40367_ml:650' key '40367_ml' not found in boundaries.
# Binned token '40367_ml:700' key '40367_ml' not found in boundaries.
# Binned token '40405_ml:161' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:186' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:197' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:302' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:382' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:396' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:490' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:495' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:499' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:790' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:806' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:862' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:900' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:984' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:990' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:998' key '40405_ml' not found in boundaries.
# Binned token '40405_ml:999' key '40405_ml' not found in boundaries.
# Binned token '40425_ml:2000' key '40425_ml' not found in boundaries.
# Binned token '40473_ml:110' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:25' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:30' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:35' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:40' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:45' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:50' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:60' key '40473_ml' not found in boundaries.
# Binned token '40473_ml:80' key '40473_ml' not found in boundaries.
# Binned token '40537_ml:10' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:22' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:3' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:37' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:4' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:5' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:6' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:7' key '40537_ml' not found in boundaries.
# Binned token '40537_ml:8' key '40537_ml' not found in boundaries.
# Binned token '40580_:0' key '40580_' not found in boundaries.
# Binned token '40652_ml:100' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:15' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:20' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:25' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:40' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:45' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:50' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:60' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:65' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:70' key '40652_ml' not found in boundaries.
# Binned token '40652_ml:80' key '40652_ml' not found in boundaries.
# Binned token '43174_:0' key '43174_' not found in boundaries.
# Binned token '43174_ml:0' key '43174_ml' not found in boundaries.
# Binned token '43175_:0' key '43175_' not found in boundaries.
# Token '50802_mEq/L:13' has invalid bin index 13.
# Binned token '50803_mEq/L:17' key '50803_mEq/L' not found in boundaries.
# Binned token '50803_mEq/L:18' key '50803_mEq/L' not found in boundaries.
# Binned token '50803_mEq/L:20' key '50803_mEq/L' not found in boundaries.
# Binned token '50803_mEq/L:21' key '50803_mEq/L' not found in boundaries.
# Binned token '50803_mEq/L:25' key '50803_mEq/L' not found in boundaries.
# Binned token '50803_mEq/L:26' key '50803_mEq/L' not found in boundaries.
# Binned token '50804_MEQ/L:15' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:16' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:17' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:19' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:20' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:21' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:22' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:23' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:24' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:25' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:26' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:27' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:28' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:29' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:30' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:31' key '50804_MEQ/L' not found in boundaries.
# Binned token '50804_MEQ/L:32' key '50804_MEQ/L' not found in boundaries.
# Token '50804_mEq/L:15' has invalid bin index 15.
# Token '50806_mEq/L:18' has invalid bin index 18.
# Token '50810_%:15' has invalid bin index 15.
# Binned token '50814_%:3' key '50814_%' not found in boundaries.
# Binned token '50815_L/min:1' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:10' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:16' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:2' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:200' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:3' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:4' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:5' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:6' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:90' key '50815_L/min' not found in boundaries.
# Binned token '50815_L/min:94' key '50815_L/min' not found in boundaries.
# Token '50816_%:8' has invalid bin index 8.
# Token '50816_:9' has invalid bin index 9.
# Token '50817_%:12' has invalid bin index 12.
# Token '50817_:13' has invalid bin index 13.
# Token '50818_MM HG:18' has invalid bin index 18.
# Binned token '50819_:0' key '50819_' not found in boundaries.
# Binned token '50819_:10' key '50819_' not found in boundaries.
# Binned token '50819_:12' key '50819_' not found in boundaries.
# Binned token '50819_:13' key '50819_' not found in boundaries.
# Binned token '50819_:14' key '50819_' not found in boundaries.
# Binned token '50819_:15' key '50819_' not found in boundaries.
# Binned token '50819_:16' key '50819_' not found in boundaries.
# Binned token '50819_:18' key '50819_' not found in boundaries.
# Binned token '50819_:20' key '50819_' not found in boundaries.
# Binned token '50819_:5' key '50819_' not found in boundaries.
# Binned token '50819_:6' key '50819_' not found in boundaries.
# Binned token '50819_:8' key '50819_' not found in boundaries.
# Token '50820_UNITS:18' has invalid bin index 18.
# Token '50822_mEq/L:17' has invalid bin index 17.
# Token '50823_:19' has invalid bin index 19.
# Token '50824_mEq/L:14' has invalid bin index 14.
# Token '50825_:18' has invalid bin index 18.
# Token '50826_:12' has invalid bin index 12.
# Binned token '50842_mg/dL:85' key '50842_mg/dL' not found in boundaries.
# Binned token '50843_IU/L:78' key '50843_IU/L' not found in boundaries.
# Token '50862_g/dL:16' has invalid bin index 16.
# Binned token '50866_umol/L:16' key '50866_umol/L' not found in boundaries.
# Binned token '50866_umol/L:51' key '50866_umol/L' not found in boundaries.
# Token '50868_mEq/L:13' has invalid bin index 13.
# Token '50882_mEq/L:15' has invalid bin index 15.
# Binned token '50890_mg/dL:55' key '50890_mg/dL' not found in boundaries.
# Binned token '50891_mg/dL:13' key '50891_mg/dL' not found in boundaries.
# Token '50902_mEq/L:18' has invalid bin index 18.
# Binned token '50904_mg/dL:29' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:32' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:36' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:44' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:45' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:48' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:50' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:51' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:55' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:73' key '50904_mg/dL' not found in boundaries.
# Binned token '50904_mg/dL:76' key '50904_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:101' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:118' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:129' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:51' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:62' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:66' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:74' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:87' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:97' key '50905_mg/dL' not found in boundaries.
# Binned token '50905_mg/dL:98' key '50905_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:113' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:138' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:140' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:143' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:149' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:155' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:180' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:191' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:200' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:215' key '50907_mg/dL' not found in boundaries.
# Binned token '50907_mg/dL:76' key '50907_mg/dL' not found in boundaries.
# Token '50911_ng/mL:19' has invalid bin index 19.
# Binned token '50914_ng/mL:49' key '50914_ng/mL' not found in boundaries.
# Binned token '50914_ng/mL:78' key '50914_ng/mL' not found in boundaries.
# Binned token '50922_mg/dL:10' key '50922_mg/dL' not found in boundaries.
# Binned token '50924_ng/mL:1503' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/mL:155' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/mL:34' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/mL:348' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/mL:563' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/mL:634' key '50924_ng/mL' not found in boundaries.
# Binned token '50924_ng/ml:125' key '50924_ng/ml' not found in boundaries.
# Binned token '50924_ng/ml:395' key '50924_ng/ml' not found in boundaries.
# Binned token '50924_ng/ml:86' key '50924_ng/ml' not found in boundaries.
# Binned token '50924_ng/ml:93' key '50924_ng/ml' not found in boundaries.
# Binned token '50927_IU/L:1058' key '50927_IU/L' not found in boundaries.
# Binned token '50935_MG/DL:249' key '50935_MG/DL' not found in boundaries.
# Binned token '50935_MG/DL:78' key '50935_MG/DL' not found in boundaries.
# Binned token '50935_mg/dL:186' key '50935_mg/dL' not found in boundaries.
# Binned token '50935_mg/dL:260' key '50935_mg/dL' not found in boundaries.
# Binned token '50935_mg/dL:265' key '50935_mg/dL' not found in boundaries.
# Binned token '50935_mg/dL:275' key '50935_mg/dL' not found in boundaries.
# Binned token '50935_mg/dL:302' key '50935_mg/dL' not found in boundaries.
# Binned token '50935_mg/dL:69' key '50935_mg/dL' not found in boundaries.
# Binned token '50949_mg/dL:121' key '50949_mg/dL' not found in boundaries.
# Binned token '50949_mg/dL:19' key '50949_mg/dL' not found in boundaries.
# Binned token '50950_mg/dL:187' key '50950_mg/dL' not found in boundaries.
# Binned token '50950_mg/dL:2463' key '50950_mg/dL' not found in boundaries.
# Binned token '50951_mg/dL:14' key '50951_mg/dL' not found in boundaries.
# Binned token '50951_mg/dL:39' key '50951_mg/dL' not found in boundaries.
# Binned token '50952_ug/dL:10' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:12' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:170' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:18' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:214' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:27' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:40' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:46' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:52' key '50952_ug/dL' not found in boundaries.
# Binned token '50952_ug/dL:8' key '50952_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:112' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:156' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:170' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:196' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:204' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:207' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:230' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:291' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:381' key '50953_ug/dL' not found in boundaries.
# Binned token '50953_ug/dL:469' key '50953_ug/dL' not found in boundaries.
# Token '50960_mg/dL:13' has invalid bin index 13.
# Binned token '50963_pg/mL:2407' key '50963_pg/mL' not found in boundaries.
# Binned token '50963_pg/mL:6439' key '50963_pg/mL' not found in boundaries.
# Binned token '50964_MOSM/L:274' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:298' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:301' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:303' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:304' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:306' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:309' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:311' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:312' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_MOSM/L:313' key '50964_MOSM/L' not found in boundaries.
# Binned token '50964_mOsm/kg:262' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:269' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:270' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:295' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:298' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:299' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:308' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:315' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:317' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:320' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:323' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:327' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:328' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:330' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50964_mOsm/kg:345' key '50964_mOsm/kg' not found in boundaries.
# Binned token '50969_%:13' key '50969_%' not found in boundaries.
# Token '50971_mEq/L:17' has invalid bin index 17.
# Token '50983_mEq/L:15' has invalid bin index 15.
# Binned token '50993_uU/ML:22' key '50993_uU/ML' not found in boundaries.
# Binned token '50993_uU/ML:31' key '50993_uU/ML' not found in boundaries.
# Binned token '50998_mg/dL:120' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:131' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:151' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:157' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:159' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:177' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:224' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:293' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:361' key '50998_mg/dL' not found in boundaries.
# Binned token '50998_mg/dL:86' key '50998_mg/dL' not found in boundaries.
# Binned token '51000_MG/DL:102' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:104' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:119' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:136' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:196' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:83' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_MG/DL:84' key '51000_MG/DL' not found in boundaries.
# Binned token '51000_mg/dL:117' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:120' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:128' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:183' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:56' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:59' key '51000_mg/dL' not found in boundaries.
# Binned token '51000_mg/dL:94' key '51000_mg/dL' not found in boundaries.
# Binned token '51001_NG/DL:41' key '51001_NG/DL' not found in boundaries.
# Binned token '51001_ng/dL:47' key '51001_ng/dL' not found in boundaries.
# Token '51003_ng/mL:18' has invalid bin index 18.
# Binned token '51008_ug/mL:31' key '51008_ug/mL' not found in boundaries.
# Binned token '51008_ug/mL:49' key '51008_ug/mL' not found in boundaries.
# Binned token '51008_ug/mL:89' key '51008_ug/mL' not found in boundaries.
# Binned token '51010_pg/mL:250' key '51010_pg/mL' not found in boundaries.
# Binned token '51010_pg/mL:345' key '51010_pg/mL' not found in boundaries.
# Binned token '51010_pg/mL:569' key '51010_pg/mL' not found in boundaries.
# Binned token '51010_pg/mL:691' key '51010_pg/mL' not found in boundaries.
# Binned token '51014_mg/dL:150' key '51014_mg/dL' not found in boundaries.
# Binned token '51014_mg/dL:57' key '51014_mg/dL' not found in boundaries.
# Binned token '51014_mg/dL:59' key '51014_mg/dL' not found in boundaries.
# Binned token '51014_mg/dL:76' key '51014_mg/dL' not found in boundaries.
# Binned token '51014_mg/dL:81' key '51014_mg/dL' not found in boundaries.
# Binned token '51018_mg/dL:113' key '51018_mg/dL' not found in boundaries.
# Binned token '51018_mg/dL:28' key '51018_mg/dL' not found in boundaries.
# Binned token '51018_mg/dL:42' key '51018_mg/dL' not found in boundaries.
# Binned token '51018_mg/dL:52' key '51018_mg/dL' not found in boundaries.
# Binned token '51026_IU/L:13' key '51026_IU/L' not found in boundaries.
# Binned token '51026_IU/L:30' key '51026_IU/L' not found in boundaries.
# Binned token '51026_IU/L:31200' key '51026_IU/L' not found in boundaries.
# Binned token '51034_mg/dL:1' key '51034_mg/dL' not found in boundaries.
# Binned token '51034_mg/dL:81' key '51034_mg/dL' not found in boundaries.
# Binned token '51035_IU/L:829' key '51035_IU/L' not found in boundaries.
# Binned token '51035_IU/L:933' key '51035_IU/L' not found in boundaries.
# Binned token '51053_mg/dL:184' key '51053_mg/dL' not found in boundaries.
# Binned token '51054_IU/L:47' key '51054_IU/L' not found in boundaries.
# Binned token '51067_mg/24hours:284' key '51067_mg/24hours' not found in boundaries.
# Binned token '51072_U/L:4959' key '51072_U/L' not found in boundaries.
# Binned token '51072_U/L:902' key '51072_U/L' not found in boundaries.
# Binned token '51073_Ratio:10' key '51073_Ratio' not found in boundaries.
# Binned token '51073_Ratio:225' key '51073_Ratio' not found in boundaries.
# Binned token '51076_mEq/L:15' key '51076_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:113' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:189' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:20' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:23' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:33' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:37' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:39' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:45' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:51' key '51078_mEq/L' not found in boundaries.
# Binned token '51078_mEq/L:87' key '51078_mEq/L' not found in boundaries.
# Binned token '51087_:24' key '51087_' not found in boundaries.
# Binned token '51094_:6' key '51094_' not found in boundaries.
# Binned token '51097_mEq/L:10' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:12' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:17' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:20' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:21' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:24' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:26' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:32' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:35' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:39' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:40' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:51' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:58' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:59' key '51097_mEq/L' not found in boundaries.
# Binned token '51097_mEq/L:74' key '51097_mEq/L' not found in boundaries.
# Binned token '51102_mg/dL:161' key '51102_mg/dL' not found in boundaries.
# Binned token '51102_mg/dL:377' key '51102_mg/dL' not found in boundaries.
# Binned token '51102_mg/dL:49' key '51102_mg/dL' not found in boundaries.
# Binned token '51102_mg/dL:64' key '51102_mg/dL' not found in boundaries.
# Binned token '51102_mg/dL:76' key '51102_mg/dL' not found in boundaries.
# Binned token '51108_mL:10' key '51108_mL' not found in boundaries.
# Binned token '51108_mL:400' key '51108_mL' not found in boundaries.
# Binned token '51110_%:1' key '51110_%' not found in boundaries.
# Binned token '51115_%:7' key '51115_%' not found in boundaries.
# Binned token '51116_%:69' key '51116_%' not found in boundaries.
# Binned token '51117_%:4' key '51117_%' not found in boundaries.
# Binned token '51118_%:10' key '51118_%' not found in boundaries.
# Binned token '51120_%:15' key '51120_%' not found in boundaries.
# Binned token '51123_%:0' key '51123_%' not found in boundaries.
# Binned token '51125_%:1' key '51125_%' not found in boundaries.
# Binned token '51127_#/CU MM:1090' key '51127_#/CU MM' not found in boundaries.
# Binned token '51128_#/CU MM:210' key '51128_#/CU MM' not found in boundaries.
# Binned token '51131_#/uL:1' key '51131_#/uL' not found in boundaries.
# Binned token '51133_#/uL:96' key '51133_#/uL' not found in boundaries.
# Binned token '51143_%:0' key '51143_%' not found in boundaries.
# Binned token '51143_%:1' key '51143_%' not found in boundaries.
# Binned token '51143_%:2' key '51143_%' not found in boundaries.
# Binned token '51143_%:3' key '51143_%' not found in boundaries.
# Binned token '51143_%:4' key '51143_%' not found in boundaries.
# Binned token '51143_%:9' key '51143_%' not found in boundaries.
# Token '51144_%:9' has invalid bin index 9.
# Binned token '51146_%:0' key '51146_%' not found in boundaries.
# Binned token '51146_%:1' key '51146_%' not found in boundaries.
# Binned token '51146_%:2' key '51146_%' not found in boundaries.
# Binned token '51148_%:0' key '51148_%' not found in boundaries.
# Binned token '51148_%:1' key '51148_%' not found in boundaries.
# Binned token '51180_%:1' key '51180_%' not found in boundaries.
# Binned token '51196_ng/mL:1162' key '51196_ng/mL' not found in boundaries.
# Binned token '51196_ng/mL:1257' key '51196_ng/mL' not found in boundaries.
# Binned token '51196_ng/mL:9084' key '51196_ng/mL' not found in boundaries.
# Binned token '51196_ng/mL:995' key '51196_ng/mL' not found in boundaries.
# Binned token '51199_#/uL:220' key '51199_#/uL' not found in boundaries.
# Binned token '51218_#/uL:2870' key '51218_#/uL' not found in boundaries.
# Binned token '51218_#/uL:50' key '51218_#/uL' not found in boundaries.
# Binned token '51232_%:2' key '51232_%' not found in boundaries.
# Token '51237_:12' has invalid bin index 12.
# Binned token '51245_%:3' key '51245_%' not found in boundaries.
# Token '51250_fL:18' has invalid bin index 18.
# Binned token '51251_%:0' key '51251_%' not found in boundaries.
# Binned token '51251_%:1' key '51251_%' not found in boundaries.
# Binned token '51251_%:2' key '51251_%' not found in boundaries.
# Binned token '51251_%:3' key '51251_%' not found in boundaries.
# Token '51254_%:19' has invalid bin index 19.
# Binned token '51255_%:0' key '51255_%' not found in boundaries.
# Binned token '51255_%:1' key '51255_%' not found in boundaries.
# Binned token '51255_%:5' key '51255_%' not found in boundaries.
# Token '51257_%:19' has invalid bin index 19.
# Binned token '51269_%:2' key '51269_%' not found in boundaries.
# Binned token '51347_%:2' key '51347_%' not found in boundaries.
# Binned token '51351_%:44' key '51351_%' not found in boundaries.
# Binned token '51351_%:48' key '51351_%' not found in boundaries.
# Binned token '51351_%:6' key '51351_%' not found in boundaries.
# Binned token '51351_%:77' key '51351_%' not found in boundaries.
# Binned token '51351_%:86' key '51351_%' not found in boundaries.
# Binned token '51351_%:91' key '51351_%' not found in boundaries.
# Binned token '51352_%:82' key '51352_%' not found in boundaries.
# Binned token '51355_%:0' key '51355_%' not found in boundaries.
# Binned token '51355_%:23' key '51355_%' not found in boundaries.
# Binned token '51355_%:36' key '51355_%' not found in boundaries.
# Binned token '51355_%:48' key '51355_%' not found in boundaries.
# Binned token '51355_%:6' key '51355_%' not found in boundaries.
# Binned token '51360_%:10' key '51360_%' not found in boundaries.
# Binned token '51360_%:17' key '51360_%' not found in boundaries.
# Binned token '51360_%:2' key '51360_%' not found in boundaries.
# Binned token '51360_%:20' key '51360_%' not found in boundaries.
# Binned token '51360_%:3' key '51360_%' not found in boundaries.
# Binned token '51360_%:4' key '51360_%' not found in boundaries.
# Binned token '51362_#/uL:1' key '51362_#/uL' not found in boundaries.
# Binned token '51362_#/uL:160' key '51362_#/uL' not found in boundaries.
# Binned token '51362_#/uL:21' key '51362_#/uL' not found in boundaries.
# Binned token '51362_#/uL:36' key '51362_#/uL' not found in boundaries.
# Binned token '51362_#/uL:48' key '51362_#/uL' not found in boundaries.
# Binned token '51362_#/uL:90' key '51362_#/uL' not found in boundaries.
# Binned token '51363_#/uL:1' key '51363_#/uL' not found in boundaries.
# Binned token '51363_#/uL:4' key '51363_#/uL' not found in boundaries.
# Binned token '51363_#/uL:6' key '51363_#/uL' not found in boundaries.
# Binned token '51386_%:7' key '51386_%' not found in boundaries.
# Binned token '51419_%:1' key '51419_%' not found in boundaries.
# Binned token '51427_%:15' key '51427_%' not found in boundaries.
# Binned token '51427_%:18' key '51427_%' not found in boundaries.
# Binned token '51427_%:3' key '51427_%' not found in boundaries.
# Binned token '51427_%:33' key '51427_%' not found in boundaries.
# Binned token '51427_%:40' key '51427_%' not found in boundaries.
# Binned token '51427_%:72' key '51427_%' not found in boundaries.
# Binned token '51428_%:12' key '51428_%' not found in boundaries.
# Binned token '51428_%:39' key '51428_%' not found in boundaries.
# Binned token '51428_%:50' key '51428_%' not found in boundaries.
# Binned token '51428_%:7' key '51428_%' not found in boundaries.
# Binned token '51429_%:2' key '51429_%' not found in boundaries.
# Binned token '51431_%:0' key '51431_%' not found in boundaries.
# Binned token '51431_%:1' key '51431_%' not found in boundaries.
# Binned token '51431_%:19' key '51431_%' not found in boundaries.
# Binned token '51431_%:20' key '51431_%' not found in boundaries.
# Binned token '51434_%:1' key '51434_%' not found in boundaries.
# Binned token '51434_%:9' key '51434_%' not found in boundaries.
# Binned token '51436_%:0' key '51436_%' not found in boundaries.
# Binned token '51436_%:20' key '51436_%' not found in boundaries.
# Binned token '51436_%:23' key '51436_%' not found in boundaries.
# Binned token '51436_%:48' key '51436_%' not found in boundaries.
# Binned token '51436_%:65' key '51436_%' not found in boundaries.
# Binned token '51436_%:75' key '51436_%' not found in boundaries.
# Binned token '51438_#/uL:0' key '51438_#/uL' not found in boundaries.
# Binned token '51438_#/uL:1903' key '51438_#/uL' not found in boundaries.
# Binned token '51438_#/uL:5120000' key '51438_#/uL' not found in boundaries.
# Binned token '51438_#/uL:65000' key '51438_#/uL' not found in boundaries.
# Binned token '51439_#/uL:0' key '51439_#/uL' not found in boundaries.
# Binned token '51439_#/uL:10000' key '51439_#/uL' not found in boundaries.
# Binned token '51439_#/uL:5625' key '51439_#/uL' not found in boundaries.
# Binned token '51439_#/uL:793' key '51439_#/uL' not found in boundaries.
# Binned token '51446_%:13' key '51446_%' not found in boundaries.
# Binned token '51447_%:67' key '51447_%' not found in boundaries.
# Binned token '51448_%:3' key '51448_%' not found in boundaries.
# Binned token '51450_%:0' key '51450_%' not found in boundaries.
# Binned token '51455_%:17' key '51455_%' not found in boundaries.
# Binned token '51457_#/uL:260' key '51457_#/uL' not found in boundaries.
# Binned token '51458_#/uL:29' key '51458_#/uL' not found in boundaries.
# Binned token '51476_#/hpf:0' key '51476_#/hpf' not found in boundaries.
# Binned token '51476_#/hpf:1' key '51476_#/hpf' not found in boundaries.
# Binned token '51476_#/hpf:2' key '51476_#/hpf' not found in boundaries.
# Binned token '51476_#/hpf:4' key '51476_#/hpf' not found in boundaries.
# Binned token '51476_#/hpf:5' key '51476_#/hpf' not found in boundaries.
# Binned token '51478_mg/dL:100' key '51478_mg/dL' not found in boundaries.
# Binned token '51478_mg/dL:250' key '51478_mg/dL' not found in boundaries.
# Binned token '51478_mg/dL:300' key '51478_mg/dL' not found in boundaries.
# Binned token '51478_mg/dL:500' key '51478_mg/dL' not found in boundaries.
# Binned token '51482_#/lpf:1' key '51482_#/lpf' not found in boundaries.
# Binned token '51482_#/lpf:4' key '51482_#/lpf' not found in boundaries.
# Binned token '51484_mg/dL:10' key '51484_mg/dL' not found in boundaries.
# Binned token '51484_mg/dL:15' key '51484_mg/dL' not found in boundaries.
# Binned token '51484_mg/dL:150' key '51484_mg/dL' not found in boundaries.
# Binned token '51484_mg/dL:40' key '51484_mg/dL' not found in boundaries.
# Binned token '51484_mg/dL:50' key '51484_mg/dL' not found in boundaries.
# Binned token '51492_mg/dL:100' key '51492_mg/dL' not found in boundaries.
# Binned token '51492_mg/dL:30' key '51492_mg/dL' not found in boundaries.
# Binned token '51492_mg/dL:500' key '51492_mg/dL' not found in boundaries.
# Token '51493_#/hpf:17' has invalid bin index 17.
# Binned token '51514_EU/dL:1' key '51514_EU/dL' not found in boundaries.
# Binned token '51514_EU/dL:8' key '51514_EU/dL' not found in boundaries.
# Binned token '51514_mg/dL:1' key '51514_mg/dL' not found in boundaries.
# Binned token '51514_mg/dL:2' key '51514_mg/dL' not found in boundaries.
# Binned token '51514_mg/dL:4' key '51514_mg/dL' not found in boundaries.
# Binned token '51516_#/hpf:0' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:1' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:2' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:25' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:26' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:3' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:37' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:4' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:5' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:76' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:8' key '51516_#/hpf' not found in boundaries.
# Binned token '51516_#/hpf:9' key '51516_#/hpf' not found in boundaries.
